# %%
import pandas as pd

# %%
df = pd.read_csv('generated_testset.csv')
df.head()
# Out:
#                                           user_input  \
# 0  Can you tell me where I can find more informat...
# 1  Is Portugal listed as a supported region in th...
# 2  As a humanitarian operations coordinator, how ...
# 3  Can u tell me what the World Metorological Org...
# 4  How did AI technology assist in both the prepa...
#
#                                   reference_contexts  \
# 0  ['[ Android ](/products-and-platforms/platform...
# 1  ['(日本語) 대한민국 (한국어) Latinoamérica (Español) الش...
# 2  ['is generated by Google AI. Generative AI is ...
# 3  ['Forecasting and preparing for hazards\n\nTim...
# 4  ['<1-hop>\n\nUsing satellite imagery to accele...
#
#                                            reference persona_name  \
# 0  You can find information about the Android pla...  Elena Vance
# 1  Yes, Portugal (Português) is listed as a regio...  Elena Vance
# 2  According to Lars Bromley, a specialist at the...  Elena Vance
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   user_input          8 non-null      str
#  1   reference_contexts  8 non-null      str
#  2   reference           8 non-null      str
#  3   persona_name        4 non-null      str
#  4   query_style         4 non-null      str
#  5   query_length        4 non-null      str
#  6   synthesizer_name    8 non-null      str
# dtypes: str(7)
# memory usage: 52.6 KB
